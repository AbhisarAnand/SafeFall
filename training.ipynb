# %% [markdown]
# ## Import Packages

# %%
from fastbook import *
from fastai.vision.widgets import *
import torch
from fastai.tabular.all import *

# %% [markdown]
# ## Constants

# %%
# Set all constants
training_data_path = "Images"
model_path = "Model/"
img_size = 128

# %% [markdown]
# ## Data Loading & Augmentation

# %%
model_data = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(img_size)
)

# %%
dls = model_data.dataloaders(training_data_path)

# %%
model_aug = model_data.new(item_tfms=Resize(img_size), batch_tfms=aug_transforms(mult=2))
dls = model_aug.dataloaders(training_data_path)
dls.train.show_batch(max_n=4, nrows=2, unique=True)

# %% [markdown]
# ## Model Training

# %%
learn = vision_learner(dls, resnet34, metrics=[accuracy, error_rate])

# %%
learning_rate = learn.lr_find()
learning_rate
# Out:
# SuggestedLRs(valley=0.0014454397605732083)

# %%
learn.fit(3, lr=learning_rate)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.100297</td>
#       <td>0.000461</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.041746</td>
#       <td>0.000007</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>01:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.022246</td>
#       <td>0.000007</td>
#       <td>1.000000</td>
#       <td>0.000000</td>
#       <td>01:05</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Results

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=5)

# %%
interp.print_classification_report()
# Out:
#               precision    recall  f1-score   support
#
#       fallen       1.00      1.00      1.00       208
#       normal       1.00      1.00      1.00       229
#
#     accuracy                           1.00       437
#    macro avg       1.00      1.00      1.00       437
# weighted avg       1.00      1.00      1.00       437

# %%
learn.export(model_path + "Model.pkl")
torch.save(learn, model_path + "Pt_Model.pt")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 learn.export(model_path + "Model.pkl")
#       2 torch.save(learn, model_path + "Pt_Model.pt")
#
# File C:\ProgramData\anaconda3\envs\greenscape\lib\site-packages\fastai\learner.py:436, in export(self, fname, pickle_module, pickle_protocol)
#     433 with warnings.catch_warnings():
#     434     #To avoid the warning that come from PyTorch about model not being checked
#     435     warnings.simplefilter("ignore")
# --> 436     torch.save(self, self.path/fname, pickle_module=pickle_module, pickle_protocol=pickle_protocol)
#     437 self.create_opt()
#     438 if state is not None: self.opt.load_state_dict(state)
#
# File C:\ProgramData\anaconda3\envs\greenscape\lib\site-packages\torch\serialization.py:618, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     615 _check_save_filelike(f)
#     617 if _use_new_zipfile_serialization:
# --> 618     with _open_zipfile_writer(f) as opened_zipfile:
#     619         _save(obj, opened_zipfile, pickle_module, pickle_protocol, _disable_byteorder_record)
#     620         return
#
# File C:\ProgramData\anaconda3\envs\greenscape\lib\site-packages\torch\serialization.py:492, in _open_zipfile_writer(name_or_buffer)
#     490 else:
#     491     container = _open_zipfile_writer_buffer
# --> 492 return container(name_or_buffer)
#
# File C:\ProgramData\anaconda3\envs\greenscape\lib\site-packages\torch\serialization.py:463, in _open_zipfile_writer_file.__init__(self, name)
#     461     super().__init__(torch._C.PyTorchFileWriter(self.file_stream))
#     462 else:
# --> 463     super().__init__(torch._C.PyTorchFileWriter(self.name))
#
# RuntimeError: Parent directory Model does not exist.

# %% [markdown]
# ## Convert the Model to ONNX Model

# %%
import torch
import torch.onnx

learn = load_learner(model_path + 'Model2.pkl')
model = learn.model.eval()
dummy_data = torch.randn(1, 3, img_size, img_size)
dummy_input = torch.autograd.Variable(dummy_data)

output_model_name = 'onnx_greenscape2.onnx'
input_name = 'image'
output_name = 'warn'

torch.onnx.export(model, dummy_input, model_path + output_model_name, input_names = [input_name], output_names = [output_name])

# %%
import onnx
onnx_model = onnx.load(model_path + output_model_name)
onnx.checker.check_model(onnx_model)
model
